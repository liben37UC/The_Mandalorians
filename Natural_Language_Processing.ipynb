# %%
import nltk


#language processing
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
import urllib.request
response =  urllib.request.urlopen('https://www.nytimes.com/2019/01/08/us/politics/trump-speech-transcript.html')
html = response.read()
from bs4 import BeautifulSoup
soup = BeautifulSoup(html,'html.parser')
text = soup.get_text(strip = True).split('body')
text = text[8]
tokens = [t for t in text.split()]
print(tokens)
# Out:
# [',(r=document.createElement("iframe")).src=e,r.id="3pCheckIframeId",r.style="display:none;",r.height=0,r.width=0,a.insertBefore(r,a.firstChild)}}function', 'a(t){if("https://static01.nyt.com"===t.origin)try{"3PCookieSupported"===t.data&&googletag.cmd.push(function(){googletag.pubads().setTargeting("cookie","true")}),"3PCookieNotSupported"===t.data&&googletag.cmd.push(function(){googletag.pubads().setTargeting("cookie","false")})}catch(t){}}function', 'r(){if(function(){if(Object.prototype.toString.call(window.HTMLElement).indexOf("Constructor")>0)return!0;if("[object', 'SafariRemoteNotification]"===(!window.safari||safari.pushNotification).toString())return!0;try{return', 'window.localStorage&&/Safari/.test(window.navigator.userAgent)}catch(t){return!1}}()){try{window.openDatabase(null,null,null,null)}catch(e){return', 't(),!0}try{localStorage.length?e():(localStorage.x=1,localStorage.removeItem("x"),e())}catch(o){navigator.cookieEnabled?t():e()}return!0}}!function(){try{googletag.cmd.push(function(){googletag.pubads().setTargeting("cookie","unknown")})}catch(t){}}(),t=function(){try{googletag.cmd.push(function(){googletag.pubads().setTargeting("cookie","private")})}catch(t){}}||function(){},e=function(){window.addEventListener("message",a,!1),i(0)}||function(){},function(){if(window.webkitRequestFileSystem)return', 'window.webkitRequestFileSystem(window.TEMPORARY,1,e,t),!0}()||r()||function(){if(!window.indexedDB&&(window.PointerEvent||window.MSPointerEvent))return', 't(),!0}()||e()};;_f.apply(null,', '[]);', '})();', '}if', "(window.NYTD.Abra('DFP_amzn')", '===', "'2_adslot_priority'", '||', "window.NYTD.Abra('DFP_amzn')", '===', "'3_no_mnet')", '{', 'function', 'createScript(url)', '{', 'var', 'newScript', '=', "document.createElement('script');", 'newScript.src', '=', 'url;', 'document.head.appendChild(newScript);', '};', 'function', 'placeAdSlot()', '{', "createScript('https://www.nytimes.com/ads/scripts-mixins472.min.js');", "createScript('https://www.nytimes.com/ads/manager472.min.js');", '}', 'placeAdSlot();', '}(function()', '{', 'var', 'AdSlot4=function(){"use', 'strict";function', '_(n,i,o){var', 't=document.getElementsByTagName("head")[0],e=document.createElement("script");i&&(e.onload=i),o&&(e.onerror=o),e.src=n,e.async=!0,t.appendChild(e)}function', 'E(n){var', 'i=document.cookie.match(new', 'RegExp("".concat(n,"=([^;]+)")));return', 'i?i[1]:""}var', 'n={adConfigPosition:1,nonPersonalized:"n",collapsed:"c",full:"f",socrates:"s"};function', 'S(){return(E("nyt-purr")[n.adConfigPosition]||"")===n.full}var', 'd=[{id:"dfp-ad-top",sizes:{large:[[728,90],[970,90],[970,250]],medium:[[728,90],[300,250]],small:[[300,250],[300,420]]}},{id:"top",sizes:{large:[[728,90],[970,90],[970,250]],medium:[[728,90],[300,250]],small:[[300,250],[300,420]]}}];return', 'function(){var', 'z=window.AdSlot4||{};z.cmd=z.cmd||[];var', 'b=!1;if(z.loadScripts)return', 'z;var', 'o,e=window.innerWidth;function', 'a(t){z.events.subscribe({name:"AdDefined",scope:"all",callback:function(n){var', 'o,i=[-1];n.sizes.forEach(function(n){n[0]<e&&n[0]>i[0]&&(i=[n])}),i[0][1]&&window.apstag.fetchBids({slots:[{slotID:n.truePosition||n.id,slotName:"".concat(n.truePosition||n.id,"_").concat(t,"_web"),sizes:(o=i[0][1],Array.isArray(o)?[[300,250],[728,90],[970,90],[970,250]].filter(function(i){return', 'o.some(function(n){return', 'n[0]===i[0]&&n[1]===i[1]})}):(console.warn("filterSizes()', 'did', 'not', 'receive', 'an', 'array"),[]))}]},function(){window.googletag.cmd.push(function(){window.apstag.setDisplayBids()})})}})}function', 'D(n,i){"art,', 'oak"!==n&&"art,oak"!==n||(n="art"),z.cmd.push(function(){var', 't,e;i&&window.apstag.fetchBids({slots:(t=o,e=n,d.reduce(function(n,i){var', 'o={slotID:i.id,slotName:"".concat(i,"_").concat(e,"_web"),sizes:i.sizes[t]};return', 'n.push(o),n},[]))},function(){window.googletag.cmd.push(function(){window.apstag.setDisplayBids()})}),a(n)})}return', 'e<=600?o="small":e<=740?o="medium":740<e&&(o="large"),z.loadScripts=functi ...

# %%
from nltk.corpus import stopwords
import re

sr= stopwords.words('english')
print(len(tokens))
clean_tokens = tokens[:]
for token in tokens:
    if token in stopwords.words('english'):
        clean_tokens.remove(token)
print(len(clean_tokens))
freq = nltk.FreqDist(clean_tokens)
freq.plot(20, cumulative=False)
# Out:
# 4325
# 2781

# %%
from collections import Counter
counts = Counter(clean_tokens)
print(counts)
# Out:
# Counter({'border': 40, 'illegal': 22, 'The': 21, 'We': 20, 'I': 20, 'American': 18, 'Democratic': 16, 'New': 16, 'president': 16, 'York': 15, 'Trump': 15, 'Trump’s': 14, 'government': 14, 'Oval': 12, 'fact': 12, 'security': 12, 'Democrats': 12, 'people': 12, 'reopen': 12, '{': 10, '=': 10, 'nation': 10, 'Americans': 10, 'children': 10, 'This': 10, 'Congress': 10, 'security.': 10, 'shutdown': 10, 'Tuesday': 8, 'night': 8, 'wall': 8, 'humanitarian': 8, 'crisis': 8, 'southern': 8, 'drugs': 8, 'border.': 8, 'secure': 8, 'requested': 8, 'barrier': 8, 'would': 8, 'get': 8, 'President': 8, 'is,': 8, '===': 7, 'Mr.': 7, 'Transcripts:': 7, 'Speech': 7, 'Immigration': 7, 'addressed': 6, 'Office': 6, 'My': 6, 'fellow': 6, 'Americans,': 6, 'tonight': 6, 'agents': 6, 'thousands': 6, 'immigrants': 6, 'country.': 6, 'way': 6, 'America': 6, 'millions': 6, 'killed': 6, 'across': 6, 'last': 6, 'years,': 6, 'criminal': 6, 'charged': 6, 'don’t': 6, 'right': 6, 'United': 6, 'used': 6, 'human': 6, 'immigration': 6, 'proposal': 6, 'stop': 6, 'professionals': 6, 'In': 6, 'many': 6, 'rise': 6, 'also': 6, 'billion': 6, 'wall.': 6, 'want': 6, 'pay': 6, 'new': 6, 'They': 6, 'need': 6, 'families': 6, 'one': 6, 'fund': 6, 'build': 6, 'must': 6, 'throughout': 6, 'work': 6, "window.NYTD.Abra('DFP_amzn')": 5, 'var': 5, 'following': 5, 'transcripts': 5, 'speech': 5, 'rebuttal,': 5, 'prepared': 5, '&': 5, 'delivered': 4, 'address': 4, 'public': 4, 'Speaker': 4, 'California': 4, 'Chuck': 4,